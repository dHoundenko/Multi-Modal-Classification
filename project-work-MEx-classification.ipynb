# %% [markdown]
# # Multi-Modal Data Fusion - Project Work: Multi-Modal Physical Exercise Classification
#
#
# In this project, real multi-modal data is studied by utilizing different techniques presented during the course. In addition, there is an optional task to try some different approaches to identify persons from the same dataset. Open MEx dataset from UCI machine learning repository is used. Idea is to apply different techniques to recognize physical exercises from wearable sensors and depth camera, user-independently.

# %% [markdown]
# ## Author(s)
# Add your information here
#
# Name(s):
# <br>Mikhail Bichagov, Danila Goncharenko
#
# Student number(s):
# <br>2304806, 2303788

# %% [markdown]
# ## Description
#
# The goal of this project is to develop user-independent pre-processing and classification models to recognize 7 different physical exercises measured by accelerometer (attached to subject's thigh) and depth camera (above the subject facing downwards recording an aerial view). All the exercises were performed subject lying down on the mat. Original dataset have also another acceleration sensor and pressure-sensitive mat, but those two modalities are ommited in this project. There are totally 30 subjects in the original dataset, and in this work subset of 10 person is utilized. Detailed description of the dataset and original data can be access in [MEx dataset @ UCI machine learning repository](https://archive.ics.uci.edu/ml/datasets/MEx#). We are providing the subset of dataset in Moodle.
#
# The project work is divided on following phases:
#
# 1. Data preparation, exploration, and visualization
# 2. Feature extraction and unimodal fusion for classification
# 3. Feature extraction and feature-level fusion for multimodal classification
# 4. Decision-level fusion for multimodal classification
# 5. Bonus task: Multimodal biometric identification of persons
#
# where 1-4 are compulsory (max. 10 points each), and 5 is optional to get bonus points (max. 5+5 points). In each phase, you should visualize and analyse the results and document the work and findings properly by text blocks and figures between the code. <b> Nice looking </b> and <b> informative </b> notebook representing your results and analysis will be part of the grading in addition to actual implementation.
#
# The results are validated using confusion matrices and F1 scores. F1 macro score is given as
# <br>
# <br>
# $
# \begin{equation}
# F1_{macro} = \frac{1}{N} \sum_i^N F1_i,
# \end{equation}
# $
# <br>
# <br>
# where $F1_i = 2  \frac{precision_i * recall_i}{precision_i + recall_i}$, and $N$ is the number of classes.
# <br>
#
# ## Learning goals
#
# After the project work, you should
#
# - be able to study real world multi-modal data
# - be able to apply different data fusion techniques to real-world problem
# - be able to evaluate the results
# - be able to analyse the outcome
# - be able to document your work properly
#
# ## Relevant lectures
#
# Lectures 1-8
#
# ## Relevant exercises
#
# Exercises 0-6
#
# ## Relevant chapters in course book
#
# Chapter 1-14
#
# ## Additional Material
#
# * Original dataset [MEx dataset @ UCI machine learning repository](https://archive.ics.uci.edu/ml/datasets/MEx#)
# * Related scientific article [MEx: Multi-modal Exercises Dataset for Human Activity Recognition](https://arxiv.org/pdf/1908.08992.pdf)

# %% [markdown]
# # 1. Data preparation, exploration, and visualization

# %% [markdown]
# <a id='task1'></a>
# <div class=" alert alert-warning">
#     <b>Assigment.</b> <b>Task 1.</b>
#
# Download data from the Moodle's Project section. Get yourself familiar with the folder structure and data. You can read the data files using the function given below. Each file consists one exercise type performed by single user. Data are divided on multiple folders. Note that, in each folder there is one long sequence of single exercise, except exercise 4 which is performed two times in different ways. Those two sequences belongs to same class. Do the following subtasks to pre-analyse data examples and to prepare the training and testing data for next tasks:
# <br>
# <br>
# <p> Read raw data from the files. Prepare and divide each data file to shorter sequences using windowing method. Similar to related article "MEx: Multi-modal Exercises Dataset for Human Activity Recognition", use 5 second window and 3 second overlapping between windows, producing several example sequences from one exercise file for classification purposes. Windowing is working so that starting from the beginning of each long exercise sequence, take 5 seconds of data points (from synchronized acceleration data and depth images) based on the time stamps. Next, move the window 2 seconds forward and take another 5 seconds of data. Then continue this until your are at the end of sequence. Each window will consists 500x3 matrix of acceleration data and 5x192 matrix of depth image data.</p>
#
# </div>

# %%
# Import relevant libraries here
from pathlib import Path
from copy import deepcopy
import numpy as np
import pandas as pd

# Enter data folder location
loc = "./MEx"

# %%
"""
    IMPORTANT: PLEASE DO NOT MODIFY THE CODE IN THIS CELL.
"""
def path_to_meta(p):
    meta = dict()
    meta["subject_id"] = p.parent.stem
    meta["exercise_id"] = p.stem.split("_")[-2]
    meta["trial"] = int(p.stem.split("_")[-1])
    meta["sensor_code"] = p.stem.split("_")[0]
    meta["sensor"] = {"act": "acc", "dc": "dc"}[meta["sensor_code"]]
    return meta

# Find, read, and compose the measurements
paths_record = Path(loc).glob("*/*/*.csv")

records = []

for path_record in paths_record:
    df = pd.read_csv(path_record, delimiter=",", header=None)
    meta = path_to_meta(path_record)
    
    if meta["sensor"] == "acc":
        col_names = ["time", "acc_0", "acc_1", "acc_2"]
        df.columns = col_names
    else:
        num_cols = df.shape[1]
        col_names = ["time", ] + [f"dc_{i}" for i in range(num_cols-1)]
        df.columns = col_names

    meta["df"] = df
    
    records.append(meta)

df_records = pd.DataFrame.from_records(records)

print(f"Total records found: {len(df_records)}")
print("Dataframe with all records:")
display(df_records.head())
print("Dataframe with one measurement series:")
display(df_records["df"].iloc[0].head())
# Out:
# Total records found: 160
# Dataframe with all records:
#   subject_id exercise_id  trial sensor_code sensor  \
# 0         01          01      1         act    acc
# 1         01          02      1         act    acc
# 2         01          03      1         act    acc
# 3         01          04      1         act    acc
# 4         01          04      2         act    acc
#
#                                                   df
# 0           time     acc_0     acc_1     acc_2
# 0 ...
# 1           time     acc_0     acc_1     acc_2
# 0 ...
# 2           time     acc_0     acc_1    acc_2
# 0  ...
# 3           time     acc_0    acc_1     acc_2
# 0  ...
# 4           time     acc_0     acc_1     acc_2
# 0 ...
# Dataframe with one measurement series:
#    time     acc_0     acc_1     acc_2
# 0   0.0 -0.515625 -0.843750 -0.131944
# 1  10.0 -0.515625 -0.853125 -0.134375
# 2  20.0 -0.515625 -0.850000 -0.140625
# 3  30.0 -0.515625 -0.862500 -0.150000
# ...

# %%
"""
    IMPORTANT: PLEASE DO NOT MODIFY THE CODE IN THIS CELL.
"""

# Extract 5-second long windows with 2-second shift (3-second overlap)

records_windowed = []

time_window = 5000.
time_offset = 2000.
    
for row_idx, row_data in df_records.iterrows():
    df_tmp = row_data["df"]
    time_start = np.min(df_tmp["time"].to_numpy())
    time_end = np.max(df_tmp["time"].to_numpy())
    
    for window_idx, t0 in enumerate(np.arange(time_start, time_end, time_offset)):
        t1 = t0 + time_window
        # Handle boundary conditions - skip the measurements from the end shorter than window size
        if t1 > time_end:
            continue
        
        tmp_data = deepcopy(row_data)
        tmp_data["window_idx"] = window_idx
        tmp_data["df"] = df_tmp[(df_tmp["time"] >= t0) &
                                (df_tmp["time"] < t1)].copy()
        
        records_windowed.append(tmp_data)
        
df_records_windowed = pd.DataFrame.from_records(records_windowed)

print(f"Total windows extracted: {len(df_records_windowed)}")
print("Dataframe with all windowed records:")
display(df_records_windowed.head())
print("Dataframe with one windowed measurement series:")
display(df_records_windowed["df"].iloc[0].head())
# Out:
# Total windows extracted: 4169
# Dataframe with all windowed records:
#   subject_id exercise_id  trial sensor_code sensor  \
# 0         01          01      1         act    acc
# 1         01          01      1         act    acc
# 2         01          01      1         act    acc
# 3         01          01      1         act    acc
# 4         01          01      1         act    acc
#
#                                                   df  window_idx
# 0         time     acc_0     acc_1     acc_2
# 0   ...           0
# 1         time     acc_0     acc_1     acc_2
# 200 ...           1
# 2         time     acc_0     acc_1     acc_2
# 400 ...           2
# 3           time     acc_0     acc_1     acc_2
# 60...           3
# 4           time     acc_0     acc_1     acc_2
# 80...           4
# Dataframe with one windowed measurement series:
#    time     acc_0     acc_1     acc_2
# 0   0.0 -0.515625 -0.843750 -0.131944
# 1  10.0 -0.515625 -0.853125 -0.134375
# ...

# %% [markdown]
# <a id='task1'></a>
# <div class=" alert alert-warning">
#
# <p> <b>1.1</b> Plot few examples of prepared data for each modalities (accelometer and depth camera). Plot acceleration sensor as multi-dimensional time-series and depth camera data as 2D image. Plot 5 second acceleration sensor and depth image sequences of person 1 and 5 performing exercises 2, 5, and 6. Take the first windowed example from the long exercise sequence. </p>
#
# </div>

# %%
# 1.1. Visualize selected samples for both modalities

### Your code begins here ###
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

### PLOT ONLY FIRST INDEX WINDOW

for j in [1,5]:
  for i in [2,5,6]:
    sns.lineplot(data = pd.melt(df_records_windowed[(df_records_windowed['subject_id'] == f'0{j}') & 
                                                      (df_records_windowed['exercise_id'] == f'0{i}') & 
                                                      (df_records_windowed['window_idx'] == 0) &
                                                      (df_records_windowed['sensor_code'] == 'act')]['df'].iloc[0],
                                                        ['time']), x = 'time', y = 'value', hue = 'variable')
    plt.title(f'Person 0{j}, Accelometer data, exersise 0{i}')
    plt.show()

    plt.imshow(df_records_windowed[(df_records_windowed['subject_id'] == f'0{j}') & 
                                                      (df_records_windowed['exercise_id'] == f'0{i}') & 
                                                      (df_records_windowed['window_idx'] == 0) &
                                                      (df_records_windowed['sensor_code'] == 'dc')]['df'].iloc[0].loc[:, df.columns!='time'])
    plt.title(f'Person 0{j}, Depth Camera data, exersise 0{i}')
    plt.show()

### Your code ends here ###

# %% [markdown]
# <a id='task1'></a>
# <div class=" alert alert-warning">
#
# <p> <b>1.2</b> Split the prepared dataset to training and testing datasets so that data of persons 1-7 are used for training and data of persons 8-10 are used for testing. In next tasks, training dataset could be further divided on (multiple) validation data folds to tune the models parameters, when needed.<br>
#
# <p> Note: Training set should have 1486 windows and testing set should have 598 windows. In training set, acceleration data will have a window without a pair with depth camera data, that window should be dropped as it doesn't have a pair.<p>
#
# Document your work, calculate the indicator statistics of training and testing datasets (number of examples, dimensions of each example) and visualize prepared examples.
#
# </div>

# %%
# 1.2. Split samples based on subject ID into training and testing datasets for futher experiments

### Your code begins here ###
training_data = df_records_windowed.loc[df_records_windowed['subject_id'].isin(['01', '02', '03', '04', '05', '06', '07',])]
test_data = df_records_windowed.loc[df_records_windowed['subject_id'].isin(['08', '09', '10'])]

training_data['duplicate'] = training_data.duplicated(subset = ['subject_id', 'exercise_id', 'trial', 'window_idx'])
training_data['Zipped_things'] = list(zip(list(training_data['subject_id']), list(training_data['exercise_id']), 
                                     list(training_data['trial']), list(training_data['window_idx'])))

training_to_keep = list(training_data['Zipped_things'][training_data['duplicate'] == True])
training_data = training_data[training_data['Zipped_things'].isin(training_to_keep)]

print (f'Training data has {len(list(training_to_keep))} windows')
print('\n')
print(training_data.head())

test_data = df_records_windowed.loc[df_records_windowed['subject_id'].isin(['08', '09', '10'])]

test_data['duplicate'] = test_data.duplicated(subset = ['subject_id', 'exercise_id', 'trial', 'window_idx'])
test_data['Zipped_things'] = list(zip(list(test_data['subject_id']), list(test_data['exercise_id']), 
                                     list(test_data['trial']), list(test_data['window_idx'])))

test_to_keep = list(test_data['Zipped_things'][test_data['duplicate'] == True])
test_data = test_data[test_data['Zipped_things'].isin(test_to_keep)]

print (f'Test data has {len(list(test_to_keep))} windows')
print('\n')
print(test_data.head())
### Your code ends here ###
# Out:
# Training data has 1486 windows
#
#
#   subject_id exercise_id  trial sensor_code sensor  \
# 0         01          01      1         act    acc
# 1         01          01      1         act    acc
# 2         01          01      1         act    acc
# 3         01          01      1         act    acc
# 4         01          01      1         act    acc
#
#                                                   df  window_idx  duplicate  \
# 0         time     acc_0     acc_1     acc_2
# 0   ...           0      False
# 1         time     acc_0     acc_1     acc_2
# 200 ...           1      False
# 2         time     acc_0     acc_1     acc_2
# 400 ...           2      False
# 3           time     acc_0     acc_1     acc_2
# 60...           3      False
# 4           time     acc_0     acc_1     acc_2
# 80...           4      False
#
#     Zipped_things
# 0  (01, 01, 1, 0)
# 1  (01, 01, 1, 1)
# 2  (01, 01, 1, 2)
# 3  (01, 01, 1, 3)
# 4  (01, 01, 1, 4)
# Test data has 598 windows
#
#
# ...

# %% [markdown]
# Lets leave below for now here. Its actually not needed for this assginemnt, but maybe mapping would be required in the future

# %%
import re
import os

new_training_data = []

for i in training_data['subject_id'].unique():
    arr_of_ex = training_data['exercise_id'].unique()
    fold = f'MEx/dc_0.05_0.05/{i}/'
    for exer in arr_of_ex:
        files = os.listdir(fold)
        if len([x for x in files if re.search(f'exercise_{exer}', x)]) > 0:
            if len([x for x in files if re.search(f'exercise_{exer}', x)]) > 1:
                ## Assuming here that is always at least 1 try
                trials = training_data['trial'][training_data['exercise_id'] == exer].unique()
                for tr in trials:
                    if len([x for x in files if re.search(f'exercise_{exer}_{tr}', x)]) > 0:
                        new_training_data.append(training_data[(training_data['subject_id'] == i) & (training_data['exercise_id'] == exer)\
                                                               & (training_data['trial'] == tr)])
            else:
                new_training_data.append(training_data[(training_data['subject_id'] == i) & (training_data['exercise_id'] == exer)])

# %%
pd.concat(new_training_data)
# Out:
#      subject_id exercise_id  trial sensor_code sensor  \
# 0            01          01      1         act    acc
# 1            01          01      1         act    acc
# 2            01          01      1         act    acc
# 3            01          01      1         act    acc
# 4            01          01      1         act    acc
# ...         ...         ...    ...         ...    ...
# 3566         07          07      1          dc     dc
# 3567         07          07      1          dc     dc
# 3568         07          07      1          dc     dc
# 3569         07          07      1          dc     dc
# 3570         07          07      1          dc     dc
#
#                                                      df  window_idx  \
# 0            time     acc_0     acc_1     acc_2
# 0   ...           0
# 1            time     acc_0     acc_1     acc_2
# 200 ...           1
# 2            time     acc_0     acc_1     acc_2
# 400 ...           2
# ...

# %% [markdown]
# # 2. Feature extraction and fusion for unimodal classification

# %% [markdown]
# <a id='task2'></a>
# <div class=" alert alert-warning">
#     <b>Assigment.</b> <b>Task 2.</b>
#
# Use the training dataset prepared in task 1. to build models based on the combination of principal component analysis (PCA), linear discriminant analysis (LDA), and nearest neighbour (NN) classifier for each modality separately and evaluate the model on test dataset. Do the subtasks given as
# <br>
# <br>
# <p> <b>2.1</b> Calculate PCA and LDA transformations to reduce the dimensionality of accelerometer data (e.g., using scikit-learn implementations). Before transformations downsample data from 100 Hz to 25 Hz (using scipy.signal.resample) to get 125x3 matrix of data for each 5 sec window. You should also standardize the values to zero mean and unit variance before the transformations. Using training dataset, fit PCA with 5-dimensional subspace (i.e., choosing the 5 largest principal components) and fit LDA with 5-dimensional subspace. Transform both train and test examples to this low-dimensional feature representation. Concatenate each sequence to single vector size of 3x(5+5). Perform the fusion of PCA and LDA similar manner as presented in Lecture 3 (pages 24-25) using NN method. Evaluate the performance on testset. Show confusion matrix and F1 scores of the results. </p>
#
# Note: Standardize the data along each axis.
# <br>
#
# Document your work, evaluate the results, and analyse the outcomes (The expected F1 score for this task should generally fall within the range of 40 to 50)
#
# </div>

# %%
# 2.1

### Your code begins here ###
import scipy
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, f1_score

training_data_act = training_data[training_data['sensor_code'] == 'act']
training_data_act['exercise_id'] = training_data_act['exercise_id'].astype(int)
test_data_act = test_data[test_data['sensor_code'] == 'act']
test_data_act['exercise_id'] = test_data_act['exercise_id'].astype(int)

sc_acc0 = StandardScaler()
sc_acc1 = StandardScaler()
sc_acc2 = StandardScaler()

pca_acc0 = PCA(n_components=5)
pca_acc1 = PCA(n_components=5)
pca_acc2 = PCA(n_components=5)

lda_acc0 = LDA(n_components=5)
lda_acc1 = LDA(n_components=5)
lda_acc2 = LDA(n_components=5)

df_to_scale_acc0 = pd.DataFrame()
df_to_scale_acc1 = pd.DataFrame()
df_to_scale_acc2 = pd.DataFrame()

pca_df = pd.DataFrame()

for i, row in enumerate(training_data_act['df']):

    scaled_fr_values = scipy.signal.resample(row[['acc_0', 'acc_1', 'acc_2']], 125)
    
    new_df_acc0 = pd.DataFrame(scaled_fr_values[:,0], columns=['acc_0'])
    new_df_acc1 = pd.DataFrame(scaled_fr_values[:,1], columns=['acc_1'])
    new_df_acc2 = pd.DataFrame(scaled_fr_values[:,2], columns=['acc_2'])
    
    df_to_scale_acc0 = pd.concat([df_to_scale_acc0,new_df_acc0.T], ignore_index=True)
    df_to_scale_acc1 = pd.concat([df_to_scale_acc1,new_df_acc1.T], ignore_index=True)
    df_to_scale_acc2 = pd.concat([df_to_scale_acc2,new_df_acc2.T], ignore_index=True)


sc_acc0.fit(df_to_scale_acc0)
sc_acc1.fit(df_to_scale_acc1)
sc_acc2.fit(df_to_scale_acc2)

temp_acc0 = sc_acc0.transform(df_to_scale_acc0)
temp_acc1 = sc_acc1.transform(df_to_scale_acc1)
temp_acc2 = sc_acc2.transform(df_to_scale_acc2)

pca_acc0.fit(temp_acc0)
pca_acc1.fit(temp_acc1)
pca_acc2.fit(temp_acc2)

lda_acc0.fit(temp_acc0, training_data_act['exercise_id'])
lda_acc1.fit(temp_acc1, training_data_act['exercise_id'])
lda_acc2.fit(temp_acc2, training_data_act['exercise_id'])

for i, row in enumerate(training_data_act['df']):
    scaled_fr_values = scipy.signal.resample(row[['acc_0', 'acc_1', 'acc_2']], 125)
    new_df_acc0 = pd.DataFrame(scaled_fr_values[:,0], columns=['acc_0'])
    new_df_acc1 = pd.DataFrame(scaled_fr_values[:,1], columns=['acc_1'])
    new_df_acc2 = pd.DataFrame(scaled_fr_values[:,2], columns=['acc_2'])

    new_df_acc0 = sc_acc0.transform(new_df_acc0.T)
    new_df_acc1 = sc_acc1.transform(new_df_acc1.T)
    new_df_acc2 = sc_acc2.transform(new_df_acc2.T)

    new_df_acc0_lda = lda_acc0.transform(new_df_acc0)
    new_df_acc1_lda = lda_acc1.transform(new_df_acc1)
    new_df_acc2_lda = lda_acc2.transform(new_df_acc2)

    new_df_acc0 = pca_acc0.transform(new_df_acc0)
    new_df_acc1 = pca_acc1.transform(new_df_acc1)
    new_df_acc2 = pca_acc2.transform(new_df_acc2)

    acc0_df = np.hstack((new_df_acc0, new_df_acc0_lda))
    acc1_df = np.hstack((new_df_acc1, new_df_acc1_lda))
    acc2_df = np.hstack((new_df_acc2, new_df_acc2_lda))
    training_data_act['df'].iloc[i] = pd.DataFrame(np.vstack((acc0_df, acc1_df, acc2_df)))

for i, row in enumerate(test_data_act['df']):
    
    scaled_fr_values = scipy.signal.resample(row[['acc_0', 'acc_1', 'acc_2']], 125)
    test_df_acc0 = pd.DataFrame(scaled_fr_values[:,0], columns=['acc_0'])
    test_df_acc1 = pd.DataFrame(scaled_fr_values[:,1], columns=['acc_1'])
    test_df_acc2 = pd.DataFrame(scaled_fr_values[:,2], columns=['acc_2'])

    test_df_acc0 = sc_acc0.transform(test_df_acc0.T)
    test_df_acc1 = sc_acc1.transform(test_df_acc1.T)
    test_df_acc2 = sc_acc2.transform(test_df_acc2.T)

    test_df_acc0_lda = lda_acc0.transform(test_df_acc0)
    test_df_acc1_lda = lda_acc1.transform(test_df_acc1)
    test_df_acc2_lda = lda_acc2.transform(test_df_acc2)

    test_df_acc0 = pca_acc0.transform(test_df_acc0)
    test_df_acc1 = pca_acc1.transform(test_df_acc1)
    test_df_acc2 = pca_acc2.transform(test_df_acc2)

    acc0_df = np.hstack((test_df_acc0, test_df_acc0_lda))
    acc1_df = np.hstack((test_df_acc1, test_df_acc1_lda))
    acc2_df = np.hstack((test_df_acc2, test_df_acc2_lda))
    test_data_act['df'].iloc[i] = pd.DataFrame(np.vstack((acc0_df, acc1_df, acc2_df)))

x_train = np.array([np.array(x) for x in np.array(training_data_act['df'])]).reshape(-1,30)
x_test = np.array([np.array(x) for x in np.array(test_data_act['df'])]).reshape(-1,30)

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train, training_data_act['exercise_id'])
predictions = knn.predict(x_test)

# Confusion Matrix
cm = confusion_matrix(test_data_act['exercise_id'], predictions)
print("Confusion Matrix:")
print(cm)

# F1 Score
f1 = f1_score(test_data_act['exercise_id'], predictions, average='macro')
print("F1 Score:", f1)
### Your code ends here ###
# Out:
# Confusion Matrix:
# [[38  7 12  0  0 28  0]
#  [ 0 26  1  0 28 29  0]
#  [ 0 41 16  0  0 29  0]
#  [ 2  0  0 78  0  0  0]
#  [ 0 29  0  0 28  0 33]
#  [ 0 27  4  0  0 57  0]
#  [ 0 30  1  0  1 14 39]]
# F1 Score: 0.48831385470607

# %%
print("training data shape for NN:", np.array([np.array(x) for x in np.array(training_data_act['df'])]).reshape(-1,30).shape)
print("testing data shape for NN:", np.array([np.array(x) for x in np.array(test_data_act['df'])]).reshape(-1,30).shape)

print("\n3x(5+5) vectors with 5 pca columns & 5 lda columns:")
training_data_act['df'][0]
# Out:
# training data shape for NN: (1486, 30)
# testing data shape for NN: (598, 30)
#
# 3x(5+5) vectors with 0-4 pca & 5-9 lda:
#            0          1         2         3         4         5         6  \
# 0  -7.031973   0.108189  1.425941 -0.427276 -1.034922 -2.587091 -0.211466
# 1  13.463812  -4.222707 -0.105760 -0.419117  0.888549 -0.195536 -1.392326
# 2  -5.292385 -12.895922 -1.905584  1.255842  0.379985 -1.042676  2.872428
#
#           7         8         9
# 0  2.451993 -0.577486 -0.473091
# 1 -0.243445 -0.876051 -1.018085
# 2 -1.701427  1.275850  0.499874

# %%
# Additional stuff

    ## values = sc.transform(scaled_fr_values)
    ## values = pca.transform(values)
    #new_df = pd.DataFrame(values.reshape(-1,3), columns=['acc_0', 'acc_1', 'acc_2'])
    
    ## new_df['time'] = time  ## I DONT KNOW WHY BUT IT DOES NOT WORK WHEN THIS IS NOT COMMENTED OUT
    ###### acc_df = np.hstack((new_df_acc0, new_df_acc0_lda, new_df_acc1, new_df_acc1_lda, new_df_acc2, new_df_acc2_lda))
    ###### training_data_act['df'].iloc[i] = pd.DataFrame(acc_df)

    #pca_df = pd.concat([pca_df,pd.DataFrame(np.array(new_df[['acc_0', 'acc_1', 'acc_2']]).flatten().reshape(1, -1))], ignore_index=True)

# for i, row in enumerate(test_data['df']):
    # scaled_fr_values = scipy.signal.resample(row[['acc_0', 'acc_1', 'acc_2']], 125)
    # values = sc.transform(scaled_fr_values)
    # time = np.arange(0,4990,40)
    # new_df = pd.DataFrame(scaled_fr_values, columns=['acc_0', 'acc_1', 'acc_2'])
    # new_df['time'] = time
    # training_data_act['df'].iloc[i] == new_df

# %% [markdown]
# <a id='task2'></a>
# <div class=" alert alert-warning">
# <p> <b>2.2</b> Use PCA and LDA transformations to reduce the dimensionality of depth images. You should also standardize the values to zero mean and unit variance before the transformations. Fit PCA and LDA for all training images (12x16, 192-dimensional in vectorized form) by choosing 5-dimensional subspace for both PCA and LDA. Transform both train and test examples to this low-dimensional feature representation. Concatenate each sequence to single vector size of 5x1x(5+5). Similar to task 2.1, do the PCA and LDA fusion using NN and evaluate the performance on testset. Show confusion matrix and F1 scores of the results. </p>
#
# Note: Standardize the data along each axis.
# <br>
#
# Document your work, evaluate the results, and analyse the outcomes (The expected F1 score for this task should generally fall within the range of 40 to 50)
#
# </div>

# %%
import cv2

training_data_dc = training_data[training_data['sensor_code'] == 'dc']

df_dep_imag = []
df_imag_flat = []

for i, row in enumerate(training_data_dc['df']):
    original_frame = np.array(row)
    # Perform the frame rate reduction by selecting every 1 second frame
    reduced_frame = original_frame[::1, :]

    # Resize the frame from 240x320 to 12x16 using OpenCV
    resized_frame = cv2.resize(reduced_frame, (12, 16))
    df_dep_imag.append(resized_frame)

    df_imag_flat.append(resized_frame.flatten())

np_dep_imag = np.array(df_dep_imag)
np_imag_flat = np.array(df_imag_flat)

print(np_dep_imag.shape)
print(np_imag_flat.shape)
# Out:
# (1486, 16, 12)
# (1486, 192)

# %%
# #WITH ARRAYS

import scipy
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.neighbors import KNeighborsClassifier
# 
training_data_act = training_data[training_data['sensor_code'] == 'act']
training_data_act['exercise_id'] = training_data_act['exercise_id'].astype(int)
test_data_act = test_data[test_data['sensor_code'] == 'act']
test_data_act['exercise_id'] = test_data_act['exercise_id'].astype(int)

sc = StandardScaler()
pca = PCA(n_components=5)
lda = LDA(n_components=5)
# 
df_to_scale = []
temp = []
# 
for row in training_data_act['df']:
    scaled_fr_values = scipy.signal.resample(row[['acc_0', 'acc_1', 'acc_2']], 125)
    temp.append(scaled_fr_values)
    df_to_scale.append(scaled_fr_values.flatten())
# 
# fit scaler, PCA, and LDA
df_to_scale = sc.fit_transform(df_to_scale)
pca.fit(df_to_scale)
lda.fit(df_to_scale, training_data_act['exercise_id'])
# 
training_data_transformed = []
for data in df_to_scale:
    data_pca = pca.transform([data])
    data_lda = lda.transform([data])
    training_data_transformed.append(np.hstack((data_pca, data_lda)))

test_data_transformed = []
for row in test_data_act['df']:
    scaled_fr_values = scipy.signal.resample(row[['acc_0', 'acc_1', 'acc_2']], 125)
    data = sc.transform([scaled_fr_values.flatten()])
    data_pca = pca.transform(data)
    data_lda = lda.transform(data)
    test_data_transformed.append(np.hstack((data_pca, data_lda)))

# Fusion of PCA and LDA using Nearest Neighbors
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(np.array(training_data_transformed).reshape((1486, 10)), training_data_act['exercise_id'])
predictions = knn.predict(np.array(test_data_transformed).reshape((-1, 10)))

# %% [markdown]
# # 3. Feature extraction and feature-level fusion for multimodal classification

# %% [markdown]
# <a id='task3'></a>
# <div class=" alert alert-warning">
#     <b>Assigment.</b> <b>Task 3.</b>
#
# Prepare new feature sets for each modality and combine them to single feature representation. Compare two classifiers from scikit-learn. Train classifiers using joint feature presentation. Evaluate and compare the result using testing dataset. Do the subtasks given as
# <br>
#
# <p> <b>3.1</b> Similar to task 2.1, calculate PCA for accelerometer, but choose now the 10 largest principal components as 10-dim feature vector for each window. In addition, for each window calculate mean and standard deviation of each three acc channels as statistical features, resulting 6-dimensional vector. Combine these to 36-dimensional final feature vector.</p>
#
# Document your work.
#
# </div>

# %%
# 3.1

### Your code begins here ###

### Your code ends here ###

# %% [markdown]
# <a id='task3'></a>
# <div class=" alert alert-warning">
#
# <p> <b>3.2</b> Similar to task 2.2, calculate the PCA for depth images using same setup, but now choose the 10 largest principal components as feature vector. Concatenate the image sequence forming 50-dimensional feature vector from each windowed example.</p>
#
# Document your work.
#
# </div>

# %%
# 3.2

### Your code begins here ###

### Your code ends here ###

# %% [markdown]
# <a id='task3'></a>
# <div class=" alert alert-warning">
#
# <p> <b>3.3</b> Form a joint feature presentation of features extracted in 3.1 and 3.2, resulting 86-dimensional feature vector for each example. Normalize data between 0-1 using the training dataset. Use support vector machine (SVM) with RBF-kernel and Gaussian naiveBayes classifier (use default parameter values for both classifiers). Train the classifiers and evaluate and compare classifiers on testset using confusion matrices and F1 scores.</p>
#
# Note: Normalize the data along each axis.
# <br>
#
# Document your work, evaluate the results, and analyse the outcomes. (The expected F1 score for this task should generally fall within the range of 55 to 70)
#
# </div>

# %%
# 3.3

### Your code begins here ###

### Your code ends here ###

# %% [markdown]
# # 4. Decision-level fusion for multimodal classification

# %% [markdown]
# <a id='task4'></a>
# <div class=" alert alert-warning">
#     <b>Assigment.</b> <b>Task 4.</b>
#
# Use features calculated for each modality in task 3. Choose base classifier for each modality from scikit-learn. Train classifiers for each modality feature presentations separately and combine the outputs in decision level. Evaluate and compare the result on testing dataset. Do the subtasks given as
# <br>
# <br>
# <p> <b>4.1</b> Use base classifiers of support vector machine (SVM) with RBF-kernel and AdaBoost classifier (with random_state=0).
# Normalize data between 0-1 using the training dataset. Train the base classifiers by tuning the model parameters (<i>C</i> parameter and RBF-kernel <i>gamma</i> in SVM as well as <i>n_estimators</i> and <i>learning_rate</i> in Adaboost) using 10-fold cross-validation on training dataset to find optimal set of parameters (hint: use GridSearchCV from scikit-learn). For grid search use the following values $C = [0.1, 1.0, 10.0, 100.0]$, $gamma=[0.1, 0.25, 0.5, 0.75, 1.0, 2.0]$, $n\_estimators = [50, 100, 500, 1000]$, and $learning\_rate = [0.1, 0.25, 0.5, 0.75,1.0]$.<br>
# Choose the best parameters and train the classifiers for each modality on whole training dataset. Is there a possibility that classifiers will overfit to training data using this parameter selection strategy? If so, why? </p>
#
# Note: Normalize the data along each axis.
# <br>
#
# Document your work, answer the given question, evaluate the results, and analyse the outcomes.
#
# </div>

# %%
# 4.1

### Your code begins here ###

### Your code ends here ###

# %% [markdown]
# <a id='task4'></a>
# <div class=" alert alert-warning">
#
#
# <p> <b>4.2</b> Predict probabilistic outputs of each trained classifier for both modalities using the test set. </p>
# <br>
# Document your work, evaluate the results, and analyse the outcomes.
#
# </div>

# %%
# 4.2

### Your code begins here ###

### Your code ends here ###

# %% [markdown]
# <a id='task4'></a>
# <div class=" alert alert-warning">
# <p> <b>4.3</b> Combine the probabilistic outputs of different modalities by fixed classification rules: max, min, prod, and sum. Evaluate, compare, and analyse the final combined results using confusion matrices and F1 scores. Show results for each base classifier combinations (i.e., $SVM_{acc}+SVM_{depth}$, $AdaBoost_{acc}+AdaBoost_{depth}$, $SVM_{acc}+AdaBoost_{depth}$, $AdaBoost_{acc}+SVM_{depth}$)</p>
# <br>
# Document your work, evaluate the results, and analyse the outcomes.
#
# </div>

# %%
# 4.3

### Your code begins here ###

### Your code ends here ###

# %% [markdown]
# # 5. Bonus task: Multimodal biometric identification of persons (optional)

# %% [markdown]
# <a id='task5'></a>
# <div class=" alert alert-warning">
#     <b>Assigment.</b> <b>Task 5.</b>
#
# Can you build a classifier that recognizes the person who is performing the exercise? Use same 10 person dataset and split it so that first 25% of each long exercise sequence is used for training and rest 75% of each sequence is used for testing the classifier. Use same 5 second windowing with 3 seconds overlap to prepare the examples. Note that, now the person identity is the class label instead of exercise type. Max. 10 points are given but you can earn points from partial solution, as well.
# <br>
# <br>
# <p> <b>5.1</b> Build a classifier to identify persons based on the features and one of the models given in task 4 (max. 5 points).</p>
# <br>
# Document your work. Evaluate and compare the results using confusion matrix and F1 score.
#
# </div>

# %%
# 5.1

### Your code begins here ###

### Your code ends here ###

# %% [markdown]
# <a id='task5'></a>
# <div class=" alert alert-warning">
#
# <p> <b>5.2</b> Can you build your own solution (using new features, new classification model or different fusion approaches) to beat the approach in Task 5.1 ? (max. 5 points) </p>
# <br>
# Document your work. Evaluate and compare the results using confusion matrix and F1 score.
#
# </div>

# %%
# 5.2

### Your code begins here ###

### Your code ends here ###
